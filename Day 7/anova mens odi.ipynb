# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
odi_20 = pd.read_csv('D:\DBDA\Adavance Stats\pandas\Men ODI Player Innings Stats - 20th Century.csv')
odi_21 = pd.read_csv('D:\DBDA\Adavance Stats\pandas\Men ODI Player Innings Stats - 21st Century.csv')

df = pd.concat([odi_20,odi_21],axis=0)
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dbda\AppData\Local\Temp\ipykernel_22428\1252922751.py:1: SyntaxWarning: invalid escape sequence '\D'
#   odi_20 = pd.read_csv('D:\DBDA\Adavance Stats\pandas\Men ODI Player Innings Stats - 20th Century.csv')
# C:\Users\dbda\AppData\Local\Temp\ipykernel_22428\1252922751.py:2: SyntaxWarning: invalid escape sequence '\D'
#   odi_21 = pd.read_csv('D:\DBDA\Adavance Stats\pandas\Men ODI Player Innings Stats - 21st Century.csv')
#            Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0                RA Smith                167*                     167
# 1                DI Gower                 158                     158
# 2               CWJ Athey                142*                     142
# ...

# %%
print(df.columns)

df.shape

print(df.isnull().sum())
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')
# Innings Player                        0
# Innings Runs Scored              200085
# Innings Runs Scored Num          200085
# Innings Minutes Batted           200085
# Innings Batted Flag              200085
# Innings Not Out Flag             200085
# Innings Balls Faced              200085
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400170 entries, 0 to 327327
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Innings Player                 400170 non-null  object
#  1   Innings Runs Scored            200085 non-null  object
#  2   Innings Runs Scored Num        200085 non-null  object
#  3   Innings Minutes Batted         200085 non-null  object
#  4   Innings Batted Flag            200085 non-null  float64
#  5   Innings Not Out Flag           200085 non-null  float64
#  6   Innings Balls Faced            200085 non-null  object
#  7   Innings Boundary Fours         200085 non-null  object
#  8   Innings Boundary Sixes         200085 non-null  object
#  9   Innings Batting Strike Rate    200085 non-null  object
#  10  Innings Number                 400170 non-null  object
#  11  Opposition                     400170 non-null  object
# ...

# %%
# Convert all object values to integer (coerce non-convertible ones to NaN)
df["Innings Runs Conceded"] = pd.to_numeric(df["Innings Runs Conceded"])

# %%
df["Innings Runs Conceded"]=df['Innings Runs Conceded'].replace('NaN', 0)

# %%
df["Innings Wickets Taken"]=df['Innings Wickets Taken'].replace('NaN', 0)

# %%
df["Innings Runs Conceded"].isnull().sum()
# Out:
# 291984

# %%
df.isnull().sum()
# Out:
# Innings Player                        0
# Innings Runs Scored              200085
# Innings Runs Scored Num          200085
# Innings Minutes Batted           200085
# Innings Batted Flag              200085
# Innings Not Out Flag             200085
# Innings Balls Faced              200085
# Innings Boundary Fours           200085
# Innings Boundary Sixes           200085
# Innings Batting Strike Rate      200085
# Innings Number                        0
# Opposition                            0
# Ground                                0
# Innings Date                          0
# Country                               0
# 50's                             200085
# 100's                            200085
# Innings Runs Scored Buckets      200085
# Innings Overs Bowled             200085
# Innings Bowled Flag              200085
# Innings Maidens Bowled           200085
# Innings Runs Conceded            200085
# Innings Wickets Taken            200085
# ...

# %%
df["Innings Runs Conceded"].dtype
# Out:
# dtype('O')

# %%
df['Bowling average']=df[df['Innings Runs Conceded']/df["Innings Wickets Taken"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\dbda\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File c:\Users\dbda\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\dbda\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
df_Eng = df[df["Country"]=="England"]
df_Aus = df[df["Country"]=="Australia"]
df_Ind = df[df["Country"]=="India"]
df_Pak = df[df["Country"]=="Pakistan"]

# %%
['Innings Runs']=srt['Innings Runs Scored Num'].str.replace('NaN', 0).astype(int)
