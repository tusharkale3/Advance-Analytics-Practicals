# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"D:\DBDA\Adavance Stats\Day 8\StudentsPerformance.csv")
df.head()

correlation_coefficient =df['reading score'].corr(df['writing score'])
print(f"Correlation coefficient :{correlation_coefficient}")


plt.scatter(df['reading score'],df['writing score'])

plt.xlabel("Reading Score")
plt.ylabel("Writing Score")

plt.title(f"Scatter plot (Correlation :{correlation_coefficient:.2f})")

#identify  potential outliers(eg. values with residual greater than 2 times the SD)

residuals = df['writing score']-df['reading score']
print(residuals)

std_deviation = residuals.std()

outliers = df[abs(residuals) >2 *std_deviation]


#Highlight potential outlier on the scatter plot

plt.scatter(outliers['reading score'],outliers['writing score'],color='red',label='outliers')
plt.legend()

plt.show()
# Out:
# Correlation coefficient :0.9545980771462478
# 0       2
# 1      -2
# 2      -2
# 3     -13
# 4      -3
#        ..
# 995    -4
# 996     0
# 997    -6
# 998    -1
# 999     0
# Length: 1000, dtype: int64

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"D:\DBDA\Adavance Stats\Day 8\loan.csv")
df.head()

correlation_coefficient =df['age'].corr(df['income'])
print(f"Correlation coefficient :{correlation_coefficient}")


plt.scatter(df['age'],df['income'])

plt.xlabel("Agee")
plt.ylabel("Income")

plt.title(f"Scatter plot (Correlation :{correlation_coefficient:.2f})")

#identify  potential outliers(eg. values with residual greater than 2 times the SD)

residuals = df['age']-df['income']
print(residuals)

std_deviation = residuals.std()

outliers = df[abs(residuals) >2 *std_deviation]


#Highlight potential outlier on the scatter plot

plt.scatter(outliers['age'],outliers['income'],color='red',label='outliers')
plt.legend()

plt.show()
# Out:
# Correlation coefficient :0.4762180840211062
# 0     -135
# 1       -4
# 2      -15
# 3      -79
# 4       -4
#       ...
# 845      2
# 846    -84
# 847     10
# 848     11
# 849     -4
# Length: 850, dtype: int64
