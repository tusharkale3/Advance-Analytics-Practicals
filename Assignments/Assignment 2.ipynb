# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Assignment 2 - 13 December 2023 - Pandas
#
# Perform data cleaning operations on a given data set and find out which of the data cleaning methods is the most appropriate of all the methods. Also state, why.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import math

# %%
df =pd.read_csv("D:/DBDA/Adavance Stats/pandas/NFL Play by Play 2009-2016 (v3).csv")
df.head()
# Out:
# C:\Users\dbda\AppData\Local\Temp\ipykernel_14288\3901890724.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("D:/DBDA/Adavance Stats/pandas/NFL Play by Play 2009-2016 (v3).csv")
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# ...

# %%
df.shape
# Out:
# (362447, 102)

# %%
df2 =df.copy()
df2.isnull().sum()
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         54218
#              ...
# Win_Prob     21993
# WPA           4817
# airWPA      220738
# yacWPA      220956
# Season           0
# Length: 102, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362447 entries, 0 to 362446
# Columns: 102 entries, Date to Season
# dtypes: float64(33), int64(31), object(38)
# memory usage: 282.1+ MB

# %%
df2.describe()
# Out:
#              GameID          Drive            qtr           down  \
# count  3.624470e+05  362447.000000  362447.000000  308229.000000
# mean   2.012664e+09      12.347088       2.578231       2.001226
# std    2.292258e+06       7.168173       1.130259       1.006003
# min    2.009091e+09       1.000000       1.000000       1.000000
# 25%    2.011091e+09       6.000000       2.000000       1.000000
# 50%    2.013091e+09      12.000000       3.000000       2.000000
# 75%    2.015091e+09      18.000000       4.000000       3.000000
# max    2.017010e+09      35.000000       5.000000       4.000000
#
#            TimeUnder       TimeSecs   PlayTimeDiff          yrdln  \
# count  362447.000000  362259.000000  362073.000000  361724.000000
# mean        7.386076    1695.234346      20.574649      28.413542
# std         4.642132    1063.065717      18.030486      13.002355
# min         0.000000    -900.000000       0.000000       1.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         54218
#              ...
# Win_Prob     21993
# WPA           4817
# airWPA      220738
# yacWPA      220956
# Season           0
# Length: 102, dtype: int64

# %%
# backward fill
df_ffill = df2.bfill()

# %%
df_ffill
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   1.0  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   1.0  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   1.0  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
# ...

# %%
df_ffill.isnull().sum()
# Out:
# Date        0
# GameID      0
# Drive       0
# qtr         0
# down        1
#            ..
# Win_Prob    0
# WPA         0
# airWPA      4
# yacWPA      4
# Season      0
# Length: 102, dtype: int64

# %%
df_ffill=df2.ffill()
df_ffill.isnull().sum()
# Out:
# Date        0
# GameID      0
# Drive       0
# qtr         0
# down        1
#            ..
# Win_Prob    0
# WPA         0
# airWPA      1
# yacWPA      1
# Season      0
# Length: 102, dtype: int64

# %%
df_new =df_ffill.dropna()

# %%
df_new.isnull().sum()
# Out:
# Date        0
# GameID      0
# Drive       0
# qtr         0
# down        0
#            ..
# Win_Prob    0
# WPA         0
# airWPA      0
# yacWPA      0
# Season      0
# Length: 102, dtype: int64

# %%
# Here in above dataset we have used forward fill(ffill)  and backward fill (bfill) methods for data cleaning purpose .
#Along with it we have used dropna method at last to remove those 4 entries having null values.
