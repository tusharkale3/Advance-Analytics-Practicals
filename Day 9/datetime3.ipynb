# %%
import pandas as pd 
from datetime import datetime

df = pd.read_csv(r"D:\DBDA\Adavance Stats\Day 9\starbucks.csv")
df
# Out:
#             Date    Close    Volume
# 0     2015-01-02  38.0061   6906098
# 1     2015-01-05  37.2781  11623796
# 2     2015-01-06  36.9748   7664340
# 3     2015-01-07  37.8848   9732554
# 4     2015-01-08  38.4961  13170548
# ...          ...      ...       ...
# 1001  2018-12-24  60.5600   6323252
# 1002  2018-12-26  63.0800  16646238
# 1003  2018-12-27  63.2000  11308081
# 1004  2018-12-28  63.3900   7712127
# 1005  2018-12-31  64.4000   7690183
#
# [1006 rows x 3 columns]

# %%
print(df.dtypes)

df = pd.read_csv(r"D:\DBDA\Adavance Stats\Day 9\starbucks.csv", index_col='Date')
# Out:
# Date       object
# Close     float64
# Volume      int64
# dtype: object

# %%
print(df.index)
# Out:
# Index(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#        '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-14', '2015-01-15',
#        ...
#        '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20', '2018-12-21',
#        '2018-12-24', '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-31'],
#       dtype='object', name='Date', length=1006)

# %%
df = pd.read_csv("D:\DBDA\Adavance Stats\Day 9\starbucks.csv", index_col='Date', parse_dates=True)
print(df.head())
print(df.index)
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dbda\AppData\Local\Temp\ipykernel_24084\3345369034.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("D:\DBDA\Adavance Stats\Day 9\starbucks.csv", index_col='Date', parse_dates=True)

# %%
# Take year end frequency sample

print(df.resample(rule='A').mean())
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
#visualize

import matplotlib.pyplot as plt 
df.Close.resample('A').mean().plot.bar()
plt.show()

# %%
title ="Monthly closing price for Starbucks"

df.Close.resample('M').max().plot.bar(figsize=(16,6),title=title)
plt.show()

# %%
# Check data range
print(df.head())
print(df.tail())

# Let us shift data by one row
print(df.shift(-5))
# Notice that original price of 2 Jan is now shown on 5 Jan, etc...
print(df.shift(-2).tail())
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
#             Close    Volume
# Date
# 2018-12-24  60.56   6323252
# 2018-12-26  63.08  16646238
# 2018-12-27  63.20  11308081
# 2018-12-28  63.39   7712127
# 2018-12-31  64.40   7690183
#               Close      Volume
# Date
# 2015-01-02  37.2361  27556706.0
# 2015-01-05  37.4415  10021486.0
# 2015-01-06  37.7401  11040702.0
# 2015-01-07  37.5301   9295084.0
# 2015-01-08  37.1381   8126602.0
# ...             ...         ...
# 2018-12-24      NaN         NaN
# 2018-12-26      NaN         NaN
# 2018-12-27      NaN         NaN
# 2018-12-28      NaN         NaN
# 2018-12-31      NaN         NaN
#
# [1006 rows x 2 columns]
#             Close      Volume
# Date
# 2018-12-24  63.20  11308081.0
# 2018-12-26  63.39   7712127.0
# 2018-12-27  64.40   7690183.0
# 2018-12-28    NaN         NaN
# ...

# %%
print(df.shift(periods=1, freq='M').head())
# Out:
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548

# %%
# Now let's add in a rolling mean This rolling method provides row entries, where every entry is then representaive of the window.

# 7 day rolling mean 
print(df.rolling(window=7).mean().head(15))

df['Close'].plot(figsize=(12,5))
df.rolling(window=7).mean()['Close'].plot();
plt.show()
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07
# 2015-01-16  37.600114  1.260380e+07
# 2015-01-20  37.515786  1.225634e+07
# 2015-01-21  37.615786  9.868837e+06
# 2015-01-22  37.783114  1.185335e+07
# 2015-01-23  38.273129  1.571999e+07

# %%
# 7 day rolling mean
pd.set_option('display.float_format', lambda x: '%.2f' % x) # Set to 2 decimal places
print(df.rolling(window=7).mean().head(15))

df['Close'].plot(figsize=(12,5))
df.rolling(window=30).mean()['Close'].plot();
plt.show()
# Out:
#             Close      Volume
# Date
# 2015-01-02    NaN         NaN
# 2015-01-05    NaN         NaN
# 2015-01-06    NaN         NaN
# 2015-01-07    NaN         NaN
# 2015-01-08    NaN         NaN
# 2015-01-09    NaN         NaN
# 2015-01-12  37.62 12382218.29
# 2015-01-13  37.58 12972876.00
# 2015-01-14  37.61 12640202.86
# 2015-01-15  37.64 12706240.29
# 2015-01-16  37.60 12603804.29
# 2015-01-20  37.52 12256340.86
# 2015-01-21  37.62  9868837.43
# 2015-01-22  37.78 11853347.43
# 2015-01-23  38.27 15719989.14
